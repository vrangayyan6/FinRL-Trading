# %% [markdown]
# # FinRL 全流程工作流示例
#
# 本 Notebook 演示从数据获取到策略训练/选股、回测与交易执行（Alpaca 纸面交易）的完整流程。
#
# 步骤概览：
# - 获取 S&P500 成分并设定研究区间
# - 使用 `data_fetcher` 获取真实基本面（开启 `align_quarter_dates=True`，并包含前瞻 `y_return` 标签）
# - 使用 `ml_strategy` 的行业滚动选股（若无行业列则回退至基础 ML 选股）并导出权重 CSV
# - 使用 `backtest_engine`（bt 库）对权重进行回测并输出指标
# - 使用 `trade_executor` 展示 Alpaca 账户状态、生成 dry-run 计划，并可选执行纸面交易
#
# 运行前准备：
# - 安装依赖：在项目根目录执行 `pip install -r requirements.txt`
# - 如需使用 FMP 或 Alpaca，请配置 `.env`（参见 `README.md` / `.env.example`）
# - 首次运行会在 `data/cache/` 生成缓存文件，避免重复拉取数据

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.24.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 2)) (1.26.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: scikit-learn>=1.3.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 4)) (1.4.1.post1)
# Requirement already satisfied: scipy>=1.11.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 5)) (1.13.0)
# Requirement already satisfied: lightgbm>=4.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 6)) (4.6.0)
# Requirement already satisfied: xgboost>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 7)) (3.0.5)
# Requirement already satisfied: matplotlib>=3.7.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 10)) (3.8.4)
# Requirement already satisfied: plotly>=5.15.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 11)) (5.18.0)
# Requirement already satisfied: seaborn>=0.12.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 12)) (0.13.2)
# Requirement already satisfied: streamlit>=1.28.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 15)) (1.31.0)
# Requirement already satisfied: yfinance>=0.2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 18)) (0.2.63)
# Requirement already satisfied: requests>=2.31.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 19)) (2.32.3)
# Requirement already satisfied: python-dotenv>=1.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 20)) (1.0.1)
# Collecting alpaca-py>=0.13.0 (from -r ../requirements.txt (line 21))
#   Downloading alpaca_py-0.42.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: bt>=1.1.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 24)) (1.1.2)
# Requirement already satisfied: pydantic>=2.5.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 27)) (2.9.2)
# Requirement already satisfied: pydantic-settings>=2.1.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 28)) (2.7.1)
# Requirement already satisfied: sqlalchemy>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 31)) (2.0.32)
# Collecting pathlib>=1.0.1 (from -r ../requirements.txt (line 34))
#   Downloading pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 35)) (4.12.2)
# Requirement already satisfied: lxml>=4.9.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 36)) (5.3.0)
# Requirement already satisfied: pytest>=7.4.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 39)) (8.3.4)
# Collecting pytest-cov>=4.1.0 (from -r ../requirements.txt (line 40))
#   Downloading pytest_cov-7.0.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: black>=23.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 41)) (24.8.0)
# Collecting flake8>=6.1.0 (from -r ../requirements.txt (line 42))
#   Using cached flake8-7.3.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting mypy>=1.7.0 (from -r ../requirements.txt (line 43))
#   Downloading mypy-1.18.2-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: torch>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 46)) (2.2.2)
# Collecting sphinx>=7.2.0 (from -r ../requirements.txt (line 49))
#   Downloading sphinx-8.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: setuptools>=68.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 52)) (75.8.0)
# Requirement already satisfied: wheel>=0.41.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from -r ../requirements.txt (line 53)) (0.41.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 3)) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from scikit-learn>=1.3.0->-r ../requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from scikit-learn>=1.3.0->-r ../requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from plotly>=5.15.0->-r ../requirements.txt (line 11)) (8.2.3)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (8.1.7)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (6.9.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (3.20.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (19.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.34.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from streamlit>=1.28.0->-r ../requirements.txt (line 15)) (6.0.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (4.2.0)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (2.4.1)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (0.11.4)
# Requirement already satisfied: websockets>=13.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 18)) (14.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from requests>=2.31.0->-r ../requirements.txt (line 19)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from requests>=2.31.0->-r ../requirements.txt (line 19)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from requests>=2.31.0->-r ../requirements.txt (line 19)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from requests>=2.31.0->-r ../requirements.txt (line 19)) (2024.12.14)
# Collecting msgpack<2.0.0,>=1.0.3 (from alpaca-py>=0.13.0->-r ../requirements.txt (line 21))
#   Downloading msgpack-1.1.1-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from alpaca-py>=0.13.0->-r ../requirements.txt (line 21)) (1.8.0)
# Requirement already satisfied: ffn>=1.1.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from bt>=1.1.0->-r ../requirements.txt (line 24)) (1.1.2)
# Requirement already satisfied: pyprind>=2.11 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from bt>=1.1.0->-r ../requirements.txt (line 24)) (2.11.3)
# Requirement already satisfied: tqdm>=4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from bt>=1.1.0->-r ../requirements.txt (line 24)) (4.66.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pydantic>=2.5.0->-r ../requirements.txt (line 27)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pydantic>=2.5.0->-r ../requirements.txt (line 27)) (2.23.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from sqlalchemy>=2.0.0->-r ../requirements.txt (line 31)) (3.0.3)
# Requirement already satisfied: colorama in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pytest>=7.4.0->-r ../requirements.txt (line 39)) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pytest>=7.4.0->-r ../requirements.txt (line 39)) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from pytest>=7.4.0->-r ../requirements.txt (line 39)) (1.5.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=4.1.0->-r ../requirements.txt (line 40))
#   Downloading coverage-7.10.7-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from black>=23.0.0->-r ../requirements.txt (line 41)) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from black>=23.0.0->-r ../requirements.txt (line 41)) (0.12.1)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8>=6.1.0->-r ../requirements.txt (line 42))
#   Using cached mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.15.0,>=2.14.0 (from flake8>=6.1.0->-r ../requirements.txt (line 42))
#   Using cached pycodestyle-2.14.0-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.5.0,>=3.4.0 (from flake8>=6.1.0->-r ../requirements.txt (line 42))
#   Using cached pyflakes-3.4.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: filelock in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from torch>=2.0.0->-r ../requirements.txt (line 46)) (3.13.3)
# Requirement already satisfied: sympy in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from torch>=2.0.0->-r ../requirements.txt (line 46)) (1.12)
# Requirement already satisfied: networkx in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from torch>=2.0.0->-r ../requirements.txt (line 46)) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from torch>=2.0.0->-r ../requirements.txt (line 46)) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from torch>=2.0.0->-r ../requirements.txt (line 46)) (2024.3.1)
# Collecting sphinxcontrib-applehelp>=1.0.7 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-devhelp>=1.0.6 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.6 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-jsmath>=1.0.1 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting sphinxcontrib-qthelp>=1.0.6 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting sphinxcontrib-serializinghtml>=1.1.9 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: Pygments>=2.17 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from sphinx>=7.2.0->-r ../requirements.txt (line 49)) (2.17.2)
# Collecting docutils<0.22,>=0.20 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting snowballstemmer>=2.2 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading snowballstemmer-3.0.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: babel>=2.13 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from sphinx>=7.2.0->-r ../requirements.txt (line 49)) (2.14.0)
# Collecting alabaster>=0.7.14 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading alabaster-1.0.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: imagesize>=1.3 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from sphinx>=7.2.0->-r ../requirements.txt (line 49)) (1.4.1)
# Collecting roman-numerals-py>=1.0.0 (from sphinx>=7.2.0->-r ../requirements.txt (line 49))
#   Downloading roman_numerals_py-3.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (4.21.1)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (1.34.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r ../requirements.txt (line 18)) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from curl_cffi>=0.7->yfinance>=0.2.0->-r ../requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: decorator>=5.0.7 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from ffn>=1.1.2->bt>=1.1.0->-r ../requirements.txt (line 24)) (5.1.1)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from ffn>=1.1.2->bt>=1.1.0->-r ../requirements.txt (line 24)) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from importlib-metadata<8,>=1.4->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from jinja2->torch>=2.0.0->-r ../requirements.txt (line 46)) (2.1.5)
# Requirement already satisfied: six>=1.5 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r ../requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from rich<14,>=10.14.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (3.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from sympy->torch>=2.0.0->-r ../requirements.txt (line 46)) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.0->-r ../requirements.txt (line 18)) (2.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (5.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\boyu\anaconda3\envs\py311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.28.0->-r ../requirements.txt (line 15)) (0.1.2)
# Downloading alpaca_py-0.42.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.2 kB ? eta -:--:--
#    ---------------------------------------- 122.2/122.2 kB ? eta 0:00:00
# Downloading pathlib-1.0.1-py3-none-any.whl (14 kB)
# Downloading pytest_cov-7.0.0-py3-none-any.whl (22 kB)
# Using cached flake8-7.3.0-py2.py3-none-any.whl (57 kB)
# Downloading mypy-1.18.2-cp311-cp311-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------- ----------------------------- 2.7/9.8 MB 82.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.8 MB 73.6 MB/s eta 0:00:01
#    ------------------------------------- -- 9.1/9.8 MB 72.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 62.1 MB/s eta 0:00:00
# Downloading sphinx-8.2.3-py3-none-any.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    -------------------------------------- - 3.4/3.6 MB 106.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 76.2 MB/s eta 0:00:00
# Downloading alabaster-1.0.0-py3-none-any.whl (13 kB)
# Downloading coverage-7.10.7-cp311-cp311-win_amd64.whl (221 kB)
#    ---------------------------------------- 0.0/221.4 kB ? eta -:--:--
#    ---------------------------------------- 221.4/221.4 kB ? eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ---------------------------------------- 0.0/587.4 kB ? eta -:--:--
#    ---------------------------------------- 587.4/587.4 kB ? eta 0:00:00
# Using cached mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading msgpack-1.1.1-cp311-cp311-win_amd64.whl (72 kB)
#    ---------------------------------------- 0.0/72.3 kB ? eta -:--:--
#    ---------------------------------------- 72.3/72.3 kB ? eta 0:00:00
# Using cached pycodestyle-2.14.0-py2.py3-none-any.whl (31 kB)
# Using cached pyflakes-3.4.0-py2.py3-none-any.whl (63 kB)
# Downloading roman_numerals_py-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading snowballstemmer-3.0.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.3 kB ? eta -:--:--
#    ---------------------------------------- 103.3/103.3 kB ? eta 0:00:00
# Downloading sphinxcontrib_applehelp-2.0.0-py3-none-any.whl (119 kB)
#    ---------------------------------------- 0.0/119.3 kB ? eta -:--:--
#    ---------------------------------------- 119.3/119.3 kB ? eta 0:00:00
# Downloading sphinxcontrib_devhelp-2.0.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.5 kB ? eta -:--:--
#    ---------------------------------------- 82.5/82.5 kB ? eta 0:00:00
# Downloading sphinxcontrib_htmlhelp-2.1.0-py3-none-any.whl (98 kB)
#    ---------------------------------------- 0.0/98.7 kB ? eta -:--:--
#    ---------------------------------------- 98.7/98.7 kB ? eta 0:00:00
# Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Downloading sphinxcontrib_qthelp-2.0.0-py3-none-any.whl (88 kB)
#    ---------------------------------------- 0.0/88.7 kB ? eta -:--:--
#    ---------------------------------------- 88.7/88.7 kB 5.2 MB/s eta 0:00:00
# Downloading sphinxcontrib_serializinghtml-2.0.0-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB ? eta 0:00:00
# Installing collected packages: pathlib, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, snowballstemmer, roman-numerals-py, pyflakes, pycodestyle, mypy, msgpack, mccabe, docutils, coverage, alabaster, sphinx, flake8, pytest-cov, alpaca-py
# Successfully installed alabaster-1.0.0 alpaca-py-0.42.2 coverage-7.10.7 docutils-0.21.2 flake8-7.3.0 mccabe-0.7.0 msgpack-1.1.1 mypy-1.18.2 pathlib-1.0.1 pycodestyle-2.14.0 pyflakes-3.4.0 pytest-cov-7.0.0 roman-numerals-py-3.1.0 snowballstemmer-3.0.1 sphinx-8.2.3 sphinxcontrib-applehelp-2.0.0 sphinxcontrib-devhelp-2.0.0 sphinxcontrib-htmlhelp-2.1.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-2.0.0 sphinxcontrib-serializinghtml-2.0.0

# %%
# 环境与路径设置
import os, sys, logging
from datetime import datetime, timedelta
from pathlib import Path

# 在 Notebook 中使用工作目录推断项目根目录（本文件位于 examples/ 下）
nb_dir = Path().resolve()
project_root = str(nb_dir.parent)
print(f"project_root: {project_root}")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    sys.path.insert(0, os.path.join(project_root, 'src'))

logging.basicConfig(level=logging.INFO)
# Out:
# project_root: C:\LLM-study\FinRL-Trading-refactor

# %%
# 数据源初始化与成分/区间设定
from src.data.data_fetcher import get_data_manager, fetch_sp500_tickers

preferred_source="fmp"
# 选择数据源（自动优先 FMP / WRDS，不可用时回退 Yahoo）
manager = get_data_manager(cache_dir=str(Path(project_root) / 'data' / 'cache'), preferred_source=preferred_source)
print(manager.get_source_info())

# 获取S&P500成分（若失败会使用回退列表），并选择前若干只提高演示速度
tickers = fetch_sp500_tickers(output_path=str(Path(project_root) / 'data' / 'sp500_tickers.txt'), preferred_source=preferred_source)
print(f"Total tickers: {len(tickers)} (show first 15)", tickers[:15])

# 研究时间区间（保证覆盖数年，便于滚动）
start_date = '2000-01-01'
end_date = datetime.now().strftime('%Y-%m-%d')
print(start_date, '->', end_date)
# Out:
# project_root: C:\LLM-study\FinRL-Trading-refactor
# project_root: C:\LLM-study\FinRL-Trading-refactor
# INFO:src.data.data_store:Initialized database at data\finrl_trading.db
# INFO:src.data.data_fetcher:Using preferred data source: FMP
# INFO:src.data.data_fetcher:Using preferred data source: FMP
# {'current_source': 'FMP', 'available_sources': ['FMP'], 'cache_dir': 'C:\\LLM-study\\FinRL-Trading-refactor\\data\\cache'}
# INFO:src.data.data_store:Saved S&P 500 components for 2025-10-17
# INFO:src.data.data_fetcher:Saved S&P 500 components to database for 2025-10-17
# INFO:src.data.data_fetcher:Saved 503 tickers to C:\LLM-study\FinRL-Trading-refactor\data\sp500_tickers.txt
# Total tickers: 503 (show first 15) ['WMT', 'WSM', 'ZBRA', 'MTCH', 'CB', 'AMCR', 'KHC', 'LW', 'BMY', 'TRGP', 'SPGI', 'AEE', 'HLT', 'DAY', 'GPC']
# 2019-01-01 -> 2025-10-17

# %%
# 获取基本面（align_quarter_dates=True），并校验 y_return
import pandas as pd
from src.data.data_fetcher import fetch_fundamental_data

# 为了演示速度，可以限制股票数量，例如前 80 只；实际可扩大
# tickers_small = tickers[:80]

fundamentals = fetch_fundamental_data(
    tickers,
    start_date,
    end_date,
    # output_path=str(Path(project_root) / 'data' / 'fundamentals.csv'),
    align_quarter_dates=True,    # 将交易时间从财报发布日向后推移约2月，以对齐不同公司交易日
    preferred_source=preferred_source
)
print(f"fundamentals shape: {fundamentals.shape}")

# 基本校验：应包含 y_return（由 fetcher 计算的下一季度收益率）
if 'y_return' not in fundamentals.columns:
    raise ValueError("fundamentals 缺少 y_return，请检查 data_fetcher 实现")

# 推荐仅保留有效标签样本
aaa = fundamentals.copy()
aaa = aaa[aaa['y_return'].notna()].reset_index(drop=True)
print(f"after dropna(y_return): {aaa.shape}")

# 保存一份清洁数据
clean_path = Path(project_root) / 'data' / 'fundamentals_clean.csv'
aaa.to_csv(clean_path, index=False)
print(f"Saved cleaned fundamentals to {clean_path}")
# Out:
# INFO:src.data.data_fetcher:Loading price data for BG from cache: D:\Projects\FinRL-Trading\data\cache\prices_BG_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for TXN to D:\Projects\FinRL-Trading\data\cache\prices_TXN_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for SNA to D:\Projects\FinRL-Trading\data\cache\prices_SNA_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for AIZ to D:\Projects\FinRL-Trading\data\cache\prices_AIZ_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for EXR to D:\Projects\FinRL-Trading\data\cache\prices_EXR_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for XYZ to D:\Projects\FinRL-Trading\data\cache\prices_XYZ_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for IDXX to D:\Projects\FinRL-Trading\data\cache\prices_IDXX_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for RJF to D:\Projects\FinRL-Trading\data\cache\prices_RJF_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for MHK to D:\Projects\FinRL-Trading\data\cache\prices_MHK_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for FTNT to D:\Projects\FinRL-Trading\data\cache\prices_FTNT_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for NI to D:\Projects\FinRL-Trading\data\cache\prices_NI_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for ERIE to D:\Projects\FinRL-Trading\data\cache\prices_ERIE_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for FTV to D:\Projects\FinRL-Trading\data\cache\prices_FTV_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for ABBV to D:\Projects\FinRL-Trading\data\cache\prices_ABBV_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for J to D:\Projects\FinRL-Trading\data\cache\prices_J_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PFG to D:\Projects\FinRL-Trading\data\cache\prices_PFG_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for VLTO to D:\Projects\FinRL-Trading\data\cache\prices_VLTO_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for EG to D:\Projects\FinRL-Trading\data\cache\prices_EG_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PM to D:\Projects\FinRL-Trading\data\cache\prices_PM_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for NVDA to D:\Projects\FinRL-Trading\data\cache\prices_NVDA_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for KMB to D:\Projects\FinRL-Trading\data\cache\prices_KMB_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PNR to D:\Projects\FinRL-Trading\data\cache\prices_PNR_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CCI to D:\Projects\FinRL-Trading\data\cache\prices_CCI_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for BX to D:\Projects\FinRL-Trading\data\cache\prices_BX_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for AOS to D:\Projects\FinRL-Trading\data\cache\prices_AOS_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PANW to D:\Projects\FinRL-Trading\data\cache\prices_PANW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for AAPL to D:\Projects\FinRL-Trading\data\cache\prices_AAPL_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for USB to D:\Projects\FinRL-Trading\data\cache\prices_USB_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for TECH to D:\Projects\FinRL-Trading\data\cache\prices_TECH_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CSGP to D:\Projects\FinRL-Trading\data\cache\prices_CSGP_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CF to D:\Projects\FinRL-Trading\data\cache\prices_CF_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for MS to D:\Projects\FinRL-Trading\data\cache\prices_MS_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for GWW to D:\Projects\FinRL-Trading\data\cache\prices_GWW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for SMCI to D:\Projects\FinRL-Trading\data\cache\prices_SMCI_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for JKHY to D:\Projects\FinRL-Trading\data\cache\prices_JKHY_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for UAL to D:\Projects\FinRL-Trading\data\cache\prices_UAL_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for RTX to D:\Projects\FinRL-Trading\data\cache\prices_RTX_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for NOC to D:\Projects\FinRL-Trading\data\cache\prices_NOC_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for TSCO to D:\Projects\FinRL-Trading\data\cache\prices_TSCO_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for ALL to D:\Projects\FinRL-Trading\data\cache\prices_ALL_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for
_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for VRSN to D:\Projects\FinRL-Trading\data\cache\prices_VRSN_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for GLW to D:\Projects\FinRL-Trading\data\cache\prices_GLW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for AMAT to D:\Projects\FinRL-Trading\data\cache\prices_AMAT_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CNP to D:\Projects\FinRL-Trading\data\cache\prices_CNP_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for MTD to D:\Projects\FinRL-Trading\data\cache\prices_MTD_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CMCSA to D:\Projects\FinRL-Trading\data\cache\prices_CMCSA_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for TER to D:\Projects\FinRL-Trading\data\cache\prices_TER_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for GOOG to D:\Projects\FinRL-Trading\data\cache\prices_GOOG_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for BBY to D:\Projects\FinRL-Trading\data\cache\prices_BBY_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for SHW to D:\Projects\FinRL-Trading\data\cache\prices_SHW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CTSH to D:\Projects\FinRL-Trading\data\cache\prices_CTSH_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for WDC to D:\Projects\FinRL-Trading\data\cache\prices_WDC_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for ACGL to D:\Projects\FinRL-Trading\data\cache\prices_ACGL_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CTAS to D:\Projects\FinRL-Trading\data\cache\prices_CTAS_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for DUK to D:\Projects\FinRL-Trading\data\cache\prices_DUK_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for CVS to D:\Projects\FinRL-Trading\data\cache\prices_CVS_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for SW to D:\Projects\FinRL-Trading\data\cache\prices_SW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for NKE to D:\Projects\FinRL-Trading\data\cache\prices_NKE_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for EA to D:\Projects\FinRL-Trading\data\cache\prices_EA_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PYPL to D:\Projects\FinRL-Trading\data\cache\prices_PYPL_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for PNW to D:\Projects\FinRL-Trading\data\cache\prices_PNW_2018-07-01_2026-03-28.csv
# INFO:src.data.data_fetcher:Cached price data for INTC to D:\Projects\FinRL-Trading\data\cache\prices_INTC_2018-07-01_2026-03-28.csv
# D:\Projects\FinRL-Trading\src\data\data_fetcher.py:906: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   df['y_return'] = df.groupby('tic')['adj_close_q'].pct_change().shift(-1)
# INFO:src.data.data_fetcher:Saved fundamental data to D:\Projects\FinRL-Trading\data\fundamentals.csv
# fundamentals shape: (12898, 23)
# after dropna(y_return): (12898, 23)
# Saved cleaned fundamentals to D:\Projects\FinRL-Trading\data\fundamentals_clean.csv

# %%
# 行业滚动选股并保存权重 CSV
from src.strategies.base_strategy import StrategyConfig
from src.strategies.ml_strategy import MLStockSelectionStrategy, SectorNeutralMLStrategy

# 读取清洁基本面数据（若外部提供了 sector/gsector 列，将启用行业中性版本）
fundamentals_clean = pd.read_csv(Path(project_root) / 'data' / 'fundamentals_clean.csv')

config = StrategyConfig(
    name="ML Stock Selection",
    description="Machine learning based stock selection"
)
base_strategy = MLStockSelectionStrategy(config)
sector_config = StrategyConfig(
    name="Sector Neutral ML",
    description="Sector-neutral ML strategy"
)
sector_strategy = SectorNeutralMLStrategy(sector_config)

data_dict = { 'fundamentals': fundamentals_clean }

# 采用滚动模式：每个季度独立训练/验证并预测
test_quarters = 4
top_quantile = 0.75

# 如果存在行业列，使用行业滚动选股，否则回退基础版本
sector_col_exists = ('sector' in fundamentals_clean.columns) or ('gsector' in fundamentals_clean.columns)
if sector_col_exists:
    res = sector_strategy.generate_weights(
        data_dict,
        test_quarters=test_quarters,
        top_quantile=top_quantile,
        prediction_mode='rolling'
    )
else:
    res = base_strategy.generate_weights(
        data_dict,
        test_quarters=test_quarters,
        top_quantile=top_quantile,
        prediction_mode='rolling'
    )

weights = res.weights.copy()
print(f"weights rows: {len(weights)}")

# 保存权重
out_dir = Path(project_root) / 'data'
out_dir.mkdir(parents=True, exist_ok=True)
if sector_col_exists:
    out_path = out_dir / 'ml_weights_sector.csv'
else:
    out_path = out_dir / 'ml_weights.csv'
weights.to_csv(out_path, index=False)
print(f"Saved weights to {out_path}")
# Out:
# INFO:src.strategies.base_strategy.SectorNeutralMLStrategy:Generating sector ML weights with per-sector training
# project_root: D:\Projects\FinRL-Trading
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000602 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 926, number of used features: 18
# [LightGBM] [Info] Start training from score 0.037529
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000581 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 921, number of used features: 18
# [LightGBM] [Info] Start training from score 0.042503
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 923, number of used features: 18
# [LightGBM] [Info] Start training from score 0.039192
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000537 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 929, number of used features: 18
# [LightGBM] [Info] Start training from score 0.030665
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002302 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 932, number of used features: 18
# [LightGBM] [Info] Start training from score 0.039961
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000517 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 934, number of used features: 18
# [LightGBM] [Info] Start training from score 0.030202
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 936, number of used features: 18
# [LightGBM] [Info] Start training from score 0.030424
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000433 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1289, number of used features: 18
# [LightGBM] [Info] Start training from score 0.043520
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000455 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1286, number of used features: 18
# [LightGBM] [Info] Start training from score 0.052287
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1290, number of used features: 18
# [LightGBM] [Info] Start training from score 0.052799
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1300, number of used features: 18
# [LightGBM] [Info] Start training from score 0.050079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1308, number of used features: 18
# [LightGBM] [Info] Start training from score 0.063035
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1311, number of used features: 18
# [LightGBM] [Info] Start training from score 0.056350
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000583 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1313, number of used features: 18
# [LightGBM] [Info] Start training from score 0.050463
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4589
# [LightGBM] [Info] Number of data points in the train set: 852, number of used features: 18
# [LightGBM] [Info] Start training from score 0.034959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000461 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4588
# [LightGBM] [Info] Number of data points in the train set: 850, number of used features: 18
# [LightGBM] [Info] Start training from score 0.035698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000617 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4589
# [LightGBM] [Info] Number of data points in the train set: 852, number of used features: 18
# [LightGBM] [Info] Start training from score 0.039081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 857, number of used features: 18
# [LightGBM] [Info] Start training from score 0.034762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000571 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 860, number of used features: 18
# [LightGBM] [Info] Start training from score 0.046891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000481 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 861, number of used features: 18
# [LightGBM] [Info] Start training from score 0.047450
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000515 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4589
# [LightGBM] [Info] Number of data points in the train set: 862, number of used features: 18
# [LightGBM] [Info] Start training from score 0.039210
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1085, number of used features: 18
# [LightGBM] [Info] Start training from score 0.034517
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1087, number of used features: 18
# [LightGBM] [Info] Start training from score 0.026780
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000437 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1089, number of used features: 18
# [LightGBM] [Info] Start training from score 0.030139
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1091, number of used features: 18
# [LightGBM] [Info] Start training from score 0.028487
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1093, number of used features: 18
# [LightGBM] [Info] Start training from score 0.041822
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1094, number of used features: 18
# [LightGBM] [Info] Start training from score 0.048636
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000399 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4590
# [LightGBM] [Info] Number of data points in the train set: 1095, number of used features: 18
# [LightGBM] [Info] Start training from score 0.050389
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3324
# [LightGBM] [Info] Number of data points in the train set: 560, number of used features: 18
# [LightGBM] [Info] Start training from score 0.031263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# INFO:src.strategies.base_strategy.SectorNeutralMLStrategy:Generated sector-merged rolling weights: 785 rows across 7 dates
# weights rows: 785
# Saved weights to D:\Projects\FinRL-Trading\data\ml_weights_sector.csv

# %%
# 使用 bt 库回测权重，并输出指标
import pandas as pd
from src.backtest.backtest_engine import BacktestConfig, BacktestEngine
from src.data.data_fetcher import fetch_price_data

# 读取权重
weights_path = out_path  # 来自上一单元
weights_raw = pd.read_csv(weights_path)
assert {'date','gvkey','weight'}.issubset(weights_raw.columns), '权重文件应包含 date/gvkey/weight'
weights_raw['date'] = pd.to_datetime(weights_raw['date'])
weights_raw['gvkey'] = weights_raw['gvkey'].astype(str)
weights_raw = weights_raw.sort_values(['date','gvkey'])

# 生成权重矩阵（行：日期，列：ticker）
weight_signals = (
    weights_raw
    .pivot_table(index='date', columns='gvkey', values='weight', aggfunc='sum')
    .fillna(0.0)
    .sort_index()
)

# 过滤全 0 的行
weight_signals = weight_signals.loc[(weight_signals.sum(axis=1) > 0.0)]
assert len(weight_signals) > 0, '权重矩阵为空，无法回测'

# 回测时间区间：覆盖权重范围并向后延申 90 天
t_start = weight_signals.index.min().strftime('%Y-%m-%d')
t_end = (weight_signals.index.max() + pd.Timedelta(days=90)).strftime('%Y-%m-%d')

cfg = BacktestConfig(
    start_date=t_start,
    end_date=t_end,
    rebalance_freq='Q',
    initial_capital=1_000_000.0
)

# 拉取价格数据
tickers_bt = weight_signals.columns.tolist()
prices_long = fetch_price_data(tickers_bt, cfg.start_date, cfg.end_date)

# 运行回测
engine = BacktestEngine(cfg)
price_data_bt = engine._prepare_price_data_for_bt(prices_long)

# 对齐权重日期到可交易日并归一化
from pandas import DataFrame
common_cols = [c for c in weight_signals.columns if c in price_data_bt.columns]
weight_signals = weight_signals[common_cols]
trading_index = price_data_bt.index
pos = trading_index.get_indexer(weight_signals.index, method='bfill')
mask = pos != -1
weight_signals = weight_signals.iloc[mask]
weight_signals.index = trading_index[pos[mask]]

# 清洗每日无价格的股票并归一
aligned = []
for dt, row in weight_signals.iterrows():
    prices_today = price_data_bt.loc[dt, row.index]
    valid_cols = prices_today.dropna().index.tolist()
    if len(valid_cols) == 0:
        continue
    row_valid = row[valid_cols]
    s = row_valid.sum()
    if s <= 0:
        continue
    aligned.append((dt, (row_valid / s)))

if aligned:
    weight_signals = DataFrame({dt: vec for dt, vec in aligned}).T.sort_index()
else:
    raise ValueError('对齐后无有效权重行')

# 再次行归一
weight_signals = weight_signals.div(weight_signals.sum(axis=1), axis=0).fillna(0)

result = engine.run_backtest('ML Weights Strategy', prices_long, weight_signals)
print(f"组合年化收益: {result.annualized_return:.2%}")
for bm, ann in (result.benchmark_annualized or {}).items():
    print(f"基准 {bm} 年化收益: {ann:.2%}")

metrics_df = result.to_metrics_dataframe()
metrics_df
# Out:
# project_root: D:\Projects\FinRL-Trading
# INFO:src.data.data_fetcher:Cached price data for A to D:\Projects\FinRL-Trading\data\cache\prices_A_2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Cached price data for ABBV to D:\Projects\FinRL-Trading\data\cache\prices_ABBV_2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Cached price data for ABNB to D:\Projects\FinRL-Trading\data\cache\prices_ABNB_2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Cached price data for
2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Cached price data for XYZ to D:\Projects\FinRL-Trading\data\cache\prices_XYZ_2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Cached price data for ZTS to D:\Projects\FinRL-Trading\data\cache\prices_ZTS_2024-03-01_2025-11-30.csv
# INFO:src.data.data_fetcher:Saved price data to data\prices.csv
# INFO:src.backtest.backtest_engine.BacktestEngine:Running backtest for ML Weights Strategy using bt library
# INFO:src.backtest.backtest_engine.BacktestEngine:Price data prepared for bt: shape (395, 337)
# 100%|██████████| 1/1 [00:03<00:00,  3.45s/it]
# INFO:src.backtest.backtest_engine.BacktestEngine:Backtest period: 2024-02-29 -> 2025-09-26
# INFO:src.backtest.backtest_engine.BacktestEngine:First value: 1000000.00, Last value: 1293429.68
# INFO:src.data.data_fetcher:Cached price data for SPY to D:\Projects\FinRL-Trading\data\cache\prices_SPY_2024-03-01_2025-09-26.csv
# 100%|██████████| 1/1 [00:00<00:00, 27.03it/s]
# INFO:src.backtest.backtest_engine.BacktestEngine:Computed bt metrics for benchmark SPY
# INFO:src.data.data_fetcher:Cached price data for QQQ to D:\Projects\FinRL-Trading\data\cache\prices_QQQ_2024-03-01_2025-09-26.csv
# 100%|██████████| 1/1 [00:00<00:00, 21.74it/s]
# INFO:src.backtest.backtest_engine.BacktestEngine:Computed bt metrics for benchmark QQQ
# INFO:src.backtest.backtest_engine.BacktestEngine:Backtest completed. Annualized return: 17.76%
# INFO:src.backtest.backtest_engine.BacktestEngine:Benchmark SPY annualized: 19.12%
# INFO:src.backtest.backtest_engine.BacktestEngine:Benchmark QQQ annualized: 20.94%
# 组合年化收益: 17.76%
# 基准 SPY 年化收益: 19.12%
# 基准 QQQ 年化收益: 20.94%
#                      annual_return  annual_volatility  annualized_return  \
# ML Weights Strategy       0.177554           0.164635           0.177554
# SPY                       0.191211           0.173445           0.191211
# QQQ                       0.209442           0.218764           0.209442
#
#                       kurtosis  max_drawdown  monthly_return  monthly_sharpe  \
# ML Weights Strategy  12.011771     -0.167342        0.014302        0.379335
# SPY                  24.082016     -0.187539        0.015111        0.460803
# QQQ                  15.400121     -0.227629        0.016693        0.401735
#
#                      monthly_sortino  monthly_volatility  sharpe_ratio  \
# ML Weights Strategy         0.783229            0.037703      1.078476
# SPY                         0.784331            0.032793      1.102426
# QQQ                         0.618563            0.041551      0.957388
#
#                      skewness  sortino_ratio  total_return
# ML Weights Strategy  0.420772       1.486557      0.293430
# SPY                  1.263951       1.403373      0.317122
# QQQ                  0.933976       1.254180      0.348997

# %%
# 展示 Alpaca 账户状态、生成 dry-run，并可选 paper trading 执行
import os
from src.trading.trade_executor import create_trade_executor_from_env
import pandas as pd

weights_path = r"D:\Projects\quant\FinRL-Trading\data\EW_Nasdaq.csv"

# 仅在配置好 Alpaca API 后执行。否则会抛错并提示。
try:
    executor = create_trade_executor_from_env()
    print("Trade executor initialized. Accounts:", executor.alpaca.get_available_accounts())

    # 使用上一单元生成的权重，取最后一个交易日的组合
    df = pd.read_csv(weights_path)
    df['date'] = pd.to_datetime(df['date']).dt.date
    latest_date = df['date'].max()
    df_latest = df[df['date'] == latest_date].copy()

    # 归一化并转换为目标权重
    df_latest = df_latest.groupby('gvkey', as_index=False)['weight'].sum()
    df_latest = df_latest[df_latest['weight'] > 0]
    s = df_latest['weight'].sum()
    if s <= 0:
        raise ValueError('最新调仓日权重和为0')
    df_latest['weight'] = df_latest['weight'] / s
    target_weights = {row['gvkey']: float(row['weight']) for _, row in df_latest.iterrows()}

    # 生成 dry-run 计划（不提交）
    plan = executor.alpaca.execute_portfolio_rebalance(
        target_weights,
        account_name='default',
        dry_run=True
    )
    print('Dry-run plan generated:')
    print('Market open:', plan.get('market_open'))
    print('Used TIF:', plan.get('used_time_in_force'))
    print('Planned sells:', plan.get('orders_plan', {}).get('sell', []))
    print('Planned buys :', plan.get('orders_plan', {}).get('buy',  []))

    # 根据市场状态选择是否提交（paper trading）
    use_opg = os.getenv('USE_OPG', 'false').lower() == 'true'
    if plan.get('market_open'):
        submit = executor.alpaca.execute_portfolio_rebalance(
            target_weights,
            account_name='default'
        )
        print('Submitted during market hours. Orders placed:', submit.get('orders_placed', 0))
    else:
        if use_opg:
            submit = executor.alpaca.execute_portfolio_rebalance(
                target_weights,
                account_name='default',
                market_closed_action='opg'
            )
            print('Submitted as OPG. Orders placed:', submit.get('orders_placed', 0))
        else:
            print('Market is closed. Skipping submission. Set USE_OPG=true to submit OPG at open.')

except Exception as e:
    print('Alpaca 初始化或执行失败:', e)
    print('如需启用该单元，请配置 .env 并参考 README 中的 Alpaca 设置说明。')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 展示 Alpaca 账户状态、生成 dry-run，并可选 paper trading 执行
#       2 import os
# ----> 3 from src.trading.trade_executor import create_trade_executor_from_env
#       4 import pandas as pd
#       6 weights_path = r"D:\Projects\quant\FinRL-Trading\data\EW_Nasdaq.csv"
#
# ModuleNotFoundError: No module named 'src'

# %%
print('Planned buys :', plan.get('orders_plan', {}).get('buy',  []))
# Out:
# Planned buys : [{'symbol': 'PRGO', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ULTA', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'HOLX', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ADBE', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'FANG', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'CTAS', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ASML', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ENPH', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ADTN', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'WYNN', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'CSX', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ADSK', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'BKNG', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'DLTR', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'NTAP', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'BB', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'CDNS', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'KLAC', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'MRVL', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'NVDA', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'INTC', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'KDP', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'MSFT', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'PTC', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'ODFL', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'QGEN', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'FOXA', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'TEAM', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'LBTYK', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'MELI', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'DG', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'SBAC', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'EBAY', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'SNPS', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type': 'market', 'time_in_force': 'day'}, {'symbol': 'CCEP', 'quantity': 6.2893081761006275, 'side': 'buy', 'order_type':  ...

# %%
plan
# Out:
# {'orders_placed': 0,
#  'orders': [],
#  'orders_plan': {'sell': [],
#   'buy': [{'symbol': 'PRGO',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ULTA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'HOLX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ADBE',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FANG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CTAS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ASML',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ENPH',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ADTN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'WYNN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CSX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ADSK',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'BKNG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DLTR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'NTAP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'BB',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CDNS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'KLAC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MRVL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'NVDA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'INTC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'KDP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MSFT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PTC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ODFL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'QGEN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FOXA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TEAM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'LBTYK',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MELI',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SBAC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'EBAY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SNPS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CCEP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'LRCX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CSGP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'HSIC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'REGN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CRWD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'INCY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'NFLX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'HON',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VIAV',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'LIN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ILMN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AEP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PCAR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'RPM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'WDAY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MDB',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'KHC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DDOG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'LOGI',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CHTR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'IDXX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AZN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AVGO',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GEHC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PAYX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TXN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CIEN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AMAT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PLTR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ORCL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TRIP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'WBD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PTON',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TSN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'JD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PDD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'EXPE',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'STLD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ERIC',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AXON',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CPRT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'QCOM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'NTES',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VTRS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TTD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'BIDU',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MAT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AKAM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'WOR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VEON',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DOCU',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'RYAAY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SYK',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ISRG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FTNT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ARM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'XEL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FFIV',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PYPL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MRNA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'META',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TRI',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SHOP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FOSL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ROST',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VOD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SBUX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ZS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'EQIX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'IT',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TMUS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DXCM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TEVA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ON',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PTEN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TTWO',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'APP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MCHP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ZM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GILD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AMGN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ABNB',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'QMCO',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'INTU',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PANW',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ORLY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MNST',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'COST',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'UAL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'DASH',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GNTX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'XRAY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CHRW',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'EA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ALGN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'LULU',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'MAR',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CSCO',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FAST',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'FWONK',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GEN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AMZN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GOOGL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GRMN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'NDSN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AAPL',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'ADP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TCOM',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CHKP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'BMRN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'WTW',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'SMCI',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'RIVN',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'GFS',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'PEP',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'EXPD',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'BIIB',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'INFY',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'TSLA',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VRSK',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'CEG',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'AES',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'},
#    {'symbol': 'VRTX',
#     'quantity': 6.2893081761006275,
#     'side': 'buy',
#     'order_type': 'market',
#     'time_in_force': 'day'}]},
#  'market_open': True,
#  'used_time_in_force': 'day',
#  'target_weights': {'AAPL': 0.0062893081761006275,
#   'ABNB': 0.0062893081761006275,
#   'ADBE': 0.0062893081761006275,
#   'ADP': 0.0062893081761006275,
#   'ADSK': 0.0062893081761006275,
#   'ADTN': 0.0062893081761006275,
#   'AEP': 0.0062893081761006275,
#   'AES': 0.0062893081761006275,
#   'AKAM': 0.0062893081761006275,
#   'ALGN': 0.0062893081761006275,
#   'AMAT': 0.0062893081761006275,
#   'AMGN': 0.0062893081761006275,
#   'AMZN': 0.0062893081761006275,
#   'AN': 0.0062893081761006275,
#   'APP': 0.0062893081761006275,
#   'ARM': 0.0062893081761006275,
#   'ASML': 0.0062893081761006275,
#   'AVGO': 0.0062893081761006275,
#   'AXON': 0.0062893081761006275,
#   'AZN': 0.0062893081761006275,
#   'BB': 0.0062893081761006275,
#   'BIDU': 0.0062893081761006275,
#   'BIIB': 0.0062893081761006275,
#   'BKNG': 0.0062893081761006275,
#   'BMRN': 0.0062893081761006275,
#   'CCEP': 0.0062893081761006275,
#   'CDNS': 0.0062893081761006275,
#   'CEG': 0.0062893081761006275,
#   'CHKP': 0.0062893081761006275,
#   'CHRW': 0.0062893081761006275,
#   'CHTR': 0.0062893081761006275,
#   'CIEN': 0.0062893081761006275,
#   'COST': 0.0062893081761006275,
#   'CPRT': 0.0062893081761006275,
#   'CRWD': 0.0062893081761006275,
#   'CSCO': 0.0062893081761006275,
#   'CSGP': 0.0062893081761006275,
#   'CSX': 0.0062893081761006275,
#   'CTAS': 0.0062893081761006275,
#   'DASH': 0.0062893081761006275,
#   'DDOG': 0.0062893081761006275,
#   'RIVN': 0.0062893081761006275,
#   'ROST': 0.0062893081761006275,
#   'RPM': 0.0062893081761006275,
#   'RYAAY': 0.0062893081761006275,
#   'SBAC': 0.0062893081761006275,
#   'SBUX': 0.0062893081761006275,
#   'SHOP': 0.0062893081761006275,
#   'SMCI': 0.0062893081761006275,
#   'SNPS': 0.0062893081761006275,
#   'STLD': 0.0062893081761006275,
#   'SYK': 0.0062893081761006275,
#   'TCOM': 0.0062893081761006275,
#   'TEAM': 0.0062893081761006275,
#   'TEVA': 0.0062893081761006275,
#   'TMUS': 0.0062893081761006275,
#   'TRI': 0.0062893081761006275,
#   'TRIP': 0.0062893081761006275,
#   'TSLA': 0.0062893081761006275,
#   'TSN': 0.0062893081761006275,
#   'TTD': 0.0062893081761006275,
#   'TTWO': 0.0062893081761006275,
#   'TXN': 0.0062893081761006275,
#   'UAL': 0.0062893081761006275,
#   'ULTA': 0.0062893081761006275,
#   'VEON': 0.0062893081761006275,
#   'VIAV': 0.0062893081761006275,
#   'VOD': 0.0062893081761006275,
#   'VRSK': 0.0062893081761006275,
#   'VRTX': 0.0062893081761006275,
#   'VTRS': 0.0062893081761006275,
#   'WBD': 0.0062893081761006275,
#   'WDAY': 0.0062893081761006275,
#   'WOR': 0.0062893081761006275,
#   'WTW': 0.0062893081761006275,
#   'WYNN': 0.0062893081761006275,
#   'XEL': 0.0062893081761006275,
#   'XRAY': 0.0062893081761006275,
#   'ZM': 0.0062893081761006275,
#   'ZS': 0.0062893081761006275}}

# %%
# 读取 Alpaca 账户历史并对比基准（SPY/QQQ）single account
import logging
from datetime import datetime, timedelta, timezone
from src.trading.performance_analyzer import (
    create_alpaca_account_from_env, AlpacaManager,
    get_first_order_date, get_portfolio_history,
    get_benchmark_data, display_metrics_table, plot_performance
)

try:
    logging.basicConfig(level=logging.INFO)
    # 创建 AlpacaManager
    account = create_alpaca_account_from_env()
 
    print(account)
    #account= 'paper1'
    manager = AlpacaManager([account])
    print(f"manager is {manager}")
    # 时间区间：从第一笔订单到当前（或你也可自定义窗口）
    end_date = datetime.now(timezone.utc)
    print(f"end_date is {end_date}")
    first_order_date = get_first_order_date(manager)
    if first_order_date is None:
        raise RuntimeError('无法确定账户首笔订单日期，请确认账户有交易历史或检查API权限')

    # 保证获取到 end_date 当天数据（FMP端需要 +1 日），并给 start_date-1 天用于边界
    start_date = first_order_date - timedelta(days=1)
    start_date_str = start_date.date().isoformat()
    fmp_end_date = end_date + timedelta(days=1)
    end_date_str = fmp_end_date.date().isoformat()

    # 拉取账户权益曲线与基准
    portfolio_df = get_portfolio_history(manager, start_date, end_date)
    benchmark_df = get_benchmark_data(start_date_str, end_date_str)

    # 对齐指标与绘图（内部会自动处理对齐与空值）
    display_metrics_table(portfolio_df, benchmark_df)
    plot_performance(portfolio_df, benchmark_df)

except Exception as e:
    print('纸面交易表现分析失败:', e)
    print('如需启用该单元，请在 .env 配置 Alpaca API，并确保账户存在订单历史。')
# Out:
# AlpacaAccount(name='default', api_key='PKPWCZPOOYKF0YF2G68Z', api_secret='aRW9f6XvlYckqHtib0vOgtkxfYDsQ5qkQUIDDbF2', base_url='https://paper-api.alpaca.markets/')
# manager is <src.trading.alpaca_manager.AlpacaManager object at 0x0000015CC50E3F50>
# end_date is 2025-10-18 14:35:12.650898+00:00
# INFO:src.data.data_fetcher:Found 82 existing price records in database
# WARNING:src.data.data_fetcher:No price data to fetch
# INFO:src.data.data_fetcher:Retrieved 82 price records from database
# Performance Metrics (Aligned):
#                Metric  Portfolio        SPY        QQQ
#            Start Date 2025-08-22 2025-08-22 2025-08-22
#              End Date 2025-10-17 2025-10-17 2025-10-17
#      Total Return (%)     -0.63%      2.45%      4.77%
#     Annual Return (%)     -5.04%     21.78%     46.07%
# Annual Volatility (%)     11.47%     10.83%     13.59%
#          Sharpe Ratio      -0.61       1.83       3.24
#      Max Drawdown (%)     -2.10%     -2.98%     -3.59%

# %% [markdown]
# # 读取 Alpaca 账户历史并对比基准（SPY/QQQ）Multi- account
# ##

# %%
## 读取 Alpaca 账户历史并对比基准（SPY/QQQ）Multi- account ,using exsiting run-multi-account_performance function

import sys, importlib
sys.path.insert(0, ".")  # ensure project root on path

import src.trading.performance_analyzer as pa
importlib.reload(pa)  # force reload the latest file

from src.trading.performance_analyzer import run_multi_account_performance, _build_manager_from_env

manager = _build_manager_from_env()
run_multi_account_performance(manager)
# Out:
# INFO:src.trading.alpaca_manager.AlpacaManager:Switched to account: paper1
# project_root: C:\LLM-study\FinRL-Trading-refactor
# INFO:src.data.data_fetcher:Found 82 existing price records in database
# [DEBUG] Portfolio history from 2025-08-22 to 2025-10-18
# WARNING:src.data.data_fetcher:No price data to fetch
# INFO:src.data.data_fetcher:Retrieved 82 price records from database
# ===== paper1 =====
#
# Performance Metrics (Aligned):
#                Metric  Portfolio        SPY        QQQ
#            Start Date 2025-08-22 2025-08-22 2025-08-22
#              End Date 2025-10-17 2025-10-17 2025-10-17
#      Total Return (%)     -0.63%      2.45%      4.77%
#     Annual Return (%)     -5.04%     21.78%     46.07%
# Annual Volatility (%)     11.47%     10.83%     13.59%
#          Sharpe Ratio      -0.61       1.83       3.24
#      Max Drawdown (%)     -2.10%     -2.98%     -3.59%
# INFO:src.trading.alpaca_manager.AlpacaManager:Switched to account: paper2
# INFO:src.data.data_fetcher:Found 10 existing price records in database
# [DEBUG] Portfolio history from 2025-10-14 to 2025-10-18
# WARNING:src.data.data_fetcher:No price data to fetch
# INFO:src.data.data_fetcher:Retrieved 10 price records from database
# ===== paper2 =====
#
# Performance Metrics (Aligned):
#                Metric  Portfolio        SPY        QQQ
#            Start Date 2025-10-14 2025-10-14 2025-10-14
#              End Date 2025-10-17 2025-10-17 2025-10-17
#      Total Return (%)      0.26%     -0.44%      0.10%
#     Annual Return (%)     24.41%    -30.92%      8.33%
# Annual Volatility (%)      9.53%      7.32%      7.60%
#          Sharpe Ratio       2.35      -4.50       0.83
#      Max Drawdown (%)     -0.75%     -0.88%     -0.61%
# {'paper1':          date     equity  profit_loss  profit_loss_pct
#  0  2025-08-22  100000.00         0.00           0.0000
#  1  2025-08-23  100000.00         0.00           0.0000
#  2  2025-08-26  100000.00         0.00           0.0000
#  3  2025-08-27  100000.00         0.00           0.0000
#  4  2025-08-28  100000.00         0.00           0.0000
#  5  2025-08-29  100000.00         0.00           0.0000
#  6  2025-08-30  100181.90       181.90           0.0018
#  7  2025-09-03   99188.08      -993.82          -0.0099
#  8  2025-09-04   99398.27       210.19           0.0021
#  9  2025-09-05  100290.33       892.06           0.0090
#  10 2025-09-06  100916.35       626.02           0.0062
#  11 2025-09-09  100701.10      -215.25          -0.0021
#  12 2025-09-10  100032.72      -668.38          -0.0066
#  13 2025-09-11   99792.68      -240.04          -0.0024
#  14 2025-09-12  101200.31      1407.63           0.0141
#  15 2025-09-13  100318.33      -881.98          -0.0087
#  16 2025-09-16  100112.58      -205.75          -0.0021
#  17 2025-09-17   99947.96      -164.62          -0.0016
#  18 2025-09-18   99714.64      -233.32          -0.0023
#  19 2025-09-19  100755.14      1040.50           0.0104
#  20 2025-09-20  100342.82      -412.32          -0.0041
#  21 2025-09-23  100220.05      -122.77          -0.0012
#  22 2025-09-24  100409.50       189.45           0.0019
#  23 2025-09-25  100076.97      -332.53          -0.0033
#  24 2025-09-26   99290.14      -786.83          -0.0079
#  25 2025-09-27  100200.37       910.23           0.0092
#  26 2025-09-30  100300.64       100.27           0.0010
#  27 2025-10-01  100401.39       100.75           0.0010
#  28 2025-10-02  101063.43       662.04           0.0066
#  29 2025-10-03  101161.04        97.61           0.0010
#  30 2025-10-04  101655.45       494.41           0.0049
#  31 2025-10-07  101492.76      -162.69          -0.0016
#  32 2025-10-08  100999.40      -493.36          -0.0049
#  33 2025-10-09  101121.73       122.33           0.0012
#  34 2025-10-10  100415.43      -706.30          -0.0070
#  35 2025-10-11   97863.29     -2552.14          -0.0254
#  36 2025-10-14   99394.16      1530.87           0.0156
#  37 2025-10-15  100566.55      1172.39           0.0118
#  38 2025-10-16  101243.84       677.29           0.0067
#  39 2025-10-17   99365.48     -1878.36          -0.0186
#  40 2025-10-18  100010.13       644.65           0.0065,
#  'paper2':         date     equity  profit_loss  profit_loss_pct
#  0 2025-10-14  100189.92       189.92           0.0019
#  1 2025-10-15  100815.62       625.70           0.0062
#  2 2025-10-16  101209.36       393.74           0.0039
#  3 2025-10-17  100450.77      -758.59          -0.0075
#  4 2025-10-18  100808.24       357.47           0.0036}

# %% [markdown]
# ## 取消所有未完成的 Alpaca 订单（Paper Trading）
#
# 下方示例将列出当前未完成的订单数量，并调用 `cancel_all_orders` 批量取消所有未完成订单。仅在已正确配置 Alpaca API（Paper Trading）时执行。

# %%
# 批量取消所有未完成订单（Open Orders）
from src.trading.performance_analyzer import create_alpaca_account_from_env, AlpacaManager

try:
    account = create_alpaca_account_from_env()
    manager = AlpacaManager([account])

    # 查询当前未完成订单
    open_orders = manager.get_orders(status='open', limit=200)
    print('Open orders:', len(open_orders))

    # 批量取消
    cancelled = manager.cancel_all_orders()
    print('Cancelled orders:', cancelled)

except Exception as e:
    print('取消未完成订单失败:', e)
    print('请确认已配置 Alpaca API，并且账户为 Paper Trading。')
